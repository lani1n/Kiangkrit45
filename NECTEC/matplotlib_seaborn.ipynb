# %% [markdown]
# # Matplotlib/Seaborn
# ## Matplotlib
# ### Make a simple plot

# %%
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.plot.html

# %%
x = [1,2,3,4]

y = [1,4,9,16]

# %%
plt.plot(x,y,'-b') # -b = line + blue

plt.show()

# %%
plt.plot(x,y,'+r') # +r = plus + red

plt.show()

# %%
plt.plot(x,y,'-+b') # +r = plus + red

plt.show()

# %%
plt.plot(x, y,'-b') 

plt.title('First plot')

plt.xlabel('x_label')

plt.ylabel('y_label')

plt.show()

# %% [markdown]
# We can also specify the size of the figure using method figure() and passing the values as a tuple of the length of rows and columns to the argument figsize

# %%
plt.figure(figsize=(15,5)) # figsize = (ความยาวแนวนอน , ความยาวแนวตั้ง)

plt.plot(x,y)

plt.title('First plot')

plt.xlabel('x_label')

plt.ylabel('y_label')

plt.show()

# %%
plt.plot(x, y, 'og')

plt.title('First plot')

plt.xlabel('x_label')

plt.ylabel('y_label')

plt.show()

# %%
x_2 = [1,2,3,4]

y_2 = [1,8,27,64]

plt.plot(x, y, 'og', x_2, y_2, '^r')

plt.title('First plot')

plt.xlabel('x_label')

plt.ylabel('y_label')

plt.show()

# %% [markdown]
# ### Multiple plots in one figure
#
# We can use subplot() method to add more than one plots in one figure. In the image below, we used this method to separate two graphs which we plotted on the same axes in the previous example
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.subplot.html

# %%
plt.subplot(1,2,1) # subplot(nrows, ncols, index)
plt.plot(x, y, 'og')
plt.title('1st subplot')

plt.subplot(1,2,2)
plt.plot(x_2, y_2, '^r')
plt.title('2st subplot')

plt.suptitle('My sub-plot')
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x, y, 'og')
plt.title('1st subplot')

plt.subplot(2,1,2)
plt.plot(x_2, y_2, '^r')
plt.title('2st subplot')

plt.suptitle('My sub-plot')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))

ax[0,1].plot(x, y, 'og')
ax[0,1].set_title('1st subplot')

ax[1,0].plot(x_2, y_2, '^r')
ax[1,0].set_title('2st subplot')

plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))

ax[0,0].plot(x_2, y_2, '<y')
ax[0,0].set_title('2st subplot')

ax[0,1].plot(x, y, 'og')
ax[0,1].set_title('1st subplot')

ax[1,0].plot(x_2, y_2, '^r')
ax[1,0].set_title('2st subplot')

ax[1,1].plot(x, y, 'sk')
ax[1,1].set_title('1st subplot')

plt.show()

# %% [markdown]
# ## Creating different types of graphs with Matplotlib
#
# ### Bar chart
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.bar.html

# %%
divisions = ["Div-A","Div-B","Div-C","Div-D","Div-E"]
division_avg_marks = [70, 82, 73, 65, 68 ]

# %%
plt.bar(divisions, division_avg_marks, color = 'green') # .bar(x, y , color , ......)
plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.show()

# %%
plt.barh(divisions, division_avg_marks, color = 'green')
plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")
plt.show()

# %%
divisions = ["Div-A","Div-B","Div-C","Div-D","Div-E"]
division_avg_marks = [70, 82, 73, 65, 68 ]
boys_avg_marks = [68, 67, 77, 61, 70]

# %%
index = np.arange(5)
print(index)
# Out:
# [0 1 2 3 4]

# %%
width = 0.30

# %%
plt.bar(index, division_avg_marks, width, color = 'green', label = 'Division Marks')
plt.bar(index+width, boys_avg_marks, width, color = 'blue', label = 'Boys Marks') # index + width เพื่อขยับตำแหน่งของกราฟแกน X

plt.title("Bar Graph")
plt.xlabel("Divisions")
plt.ylabel("Marks")

plt.xticks(index + width/2, divisions) # xticks กำหนดคุณลักษณะของข้อความแกน X , yticks

plt.legend(loc='best') # แสดงคำอธิบายของกราฟ, best หาตำแหน่งที่ดีที่สุด(upper, lower, left, rigth, ...)   

plt.show()

# %%
divisions = ["Div-A","Div-B","Div-C","Div-D","Div-E"]
boys_avg_marks = [68, 67, 77, 61, 70]
girls_avg_marks = [72, 97, 69, 69, 66]

# %%
index = np.arange(5)
print(index)
# Out:
# [0 1 2 3 4]

# %%
width = 0.30

# %%
plt.bar(index, boys_avg_marks, width, color = 'blue', label = 'Boys Marks')
plt.bar(index, girls_avg_marks, width, color = 'red', label = 'Girls Marks', bottom = boys_avg_marks)

plt.title("Vertically Stacked Bar Graphs")
plt.xlabel("Divisions")
plt.ylabel("Marks")

plt.xticks(index, divisions)

plt.legend(loc='best') # แสดงคำอธิบายของกราฟ

plt.show()

# %% [markdown]
# ### Box Plot
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html

# %%
collectn_1 = np.random.normal(100, 10, 200)
collectn_2 = np.random.normal(80, 30, 200)
collectn_3 = np.random.normal(90, 20, 200)
collectn_4 = np.random.normal(70, 25, 200)

## combine these different collections into a list    
data_to_plot = [collectn_1, collectn_2, collectn_3, collectn_4]

# %%
plt.boxplot(data_to_plot,labels=['sample1','sample2','sample3','sample4'])

# boxplot(data, patch_artist=True,labels=[.....])

# labels คือ การกำหนดชือแกน X
    
plt.show()
# Out:
# C:\Users\Kiang\AppData\Local\Temp\ipykernel_20464\3773371081.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_to_plot,labels=['sample1','sample2','sample3','sample4'])

# %% [markdown]
# ### Pie Chart
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.pie.html

# %%
firms = ['Firm A', 'Firm B', 'Firm C', 'Firm D', 'Firm E']

market_share = [20, 25, 15, 10 ,20]

explode = [0, 0.1, 0, 0, 0]

plt.figure(figsize=(8,5))

plt.pie(market_share, explode = explode, labels = firms, shadow = True, startangle = 45)

# pie(ข้อมูล, explode = กำหนดข้อมูลที่ต้องแยกแสดง, labels = กำหนดชื่อชื่อ, shawdow =  กำหนดแสดงแสงเงา , startangle = กำหนดองศาเริ่ม)

plt.axis('equal') # auto,equal, on, off, scaled, tight, square

plt.legend(loc = 'best', title = 'List of Firms')

plt.show()

# %% [markdown]
# ### Histogram
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html

# %%
x = np.random.randn(1000)

# %%
x
# Out:
# array([ 6.35533741e-01, -1.33297725e+00, -1.18395185e+00, -3.15432868e-01,
#         1.04951712e+00, -9.91325867e-01,  8.30325167e-01, -1.16130570e+00,
#        -2.78031155e+00, -7.68549331e-01, -1.02181478e-01,  1.50012108e+00,
#         5.67563557e-01, -4.51735020e-01, -1.37819088e+00, -1.92981590e-01,
#         5.73599685e-01, -1.70291679e+00, -1.40834730e+00, -2.65083928e+00,
#         1.50918374e+00,  1.31714806e+00, -2.25580946e+00,  1.53713223e-01,
#         2.31867921e-01,  2.49790253e-01, -2.14867185e-01,  1.43250546e+00,
#        -1.66877716e+00,  7.71861962e-01, -9.72881084e-02,  1.13211699e+00,
#         1.23981980e+00,  7.37778288e-01,  9.33918390e-01,  5.14394638e-01,
#        -6.32349252e-01,  9.69559643e-01, -7.26781501e-01,  6.97008591e-01,
#         1.22304297e-01,  2.47919968e-01,  1.21502019e+00,  2.23873535e+00,
#        -6.05952180e-01,  1.25502048e+00,  1.48383110e+00, -8.95633956e-01,
#         2.45142702e+00, -5.88445533e-01, -7.10682877e-01, -1.35989781e+00,
#         3.91090003e-01, -1.34433341e+00,  8.37689577e-01, -1.31452015e+00,
#        -8.28130122e-01,  1.27657818e-01, -2.43532359e+00, -6.76655225e-01,
#         1.37188733e+00, -6.02068787e-01,  2.47359714e-01, -9.45158714e-01,
#         8.59735376e-01, -1.63547874e-01,  5.00871454e-01, -1.72142198e+00,
#         7.63126825e-01,  3.37411243e-01, -1.66528111e+00,  4.04304550e-01,
#         1.81003551e-01,  5.22862455e-01,  2.88420599e-01, -8.80861305e-01,
#         5.55253802e-01,  9.16856639e-02, -7.60113152e-01,  1.97303788e-01,
#        -4.96093670e-01, -2.74137531e+00, -2.63480612e-02,  5.03555379e-01,
#         1.50658567e+00, -3.05624084e-01, -1.78534006e+00,  1.39604349e+00,
#        -1.15176838e+00,  8.31136477e-01, -2.76473096e-01,  6.21510632e-02,
#        -1.44707663e+00, -1.28924219e+00, -2.08588569e+00, -1.70430666e+00,
#         2.25364261e+00,  3.09522186e-01, -8.90725219e-01, -1.90614889e-01,
#        -6.89790901e-01, -8.22586309e-01,  7.35260286e-01,  1.35675360e+00,
#         6.61090858e-01,  1.95644677e-01, -3.87126506e-01,  1.69265744e+00,
#         4.93069326e-01,  1.29345518e+00, -4.63893234e-01, -7.08597755e-01,
#         2.70226793e-01,  8.63449031e-01, -4.74294251e-01,  8.92359385e-02,
#        -3.50184285e-01,  4.03912591e-01,  1.18824653e+00, -1.25365930e-01,
#        -8.53831809e-01, -4.68911007e-01, -5.62744762e-01, -1.06459478e+00,
#         7.68084644e-01, -9.01442493e-01, -6.07970334e-01, -8.26842321e-02,
#        -1.07692377e+00, -4.22079677e-01, -5.10257166e-01,  9.89318501e-01,
#        -1.24630746e-01, -5.59597573e-01, -6.25237539e-01,  7.69518624e-01])

# %%
plt.title("Histogram")
plt.xlabel("Random Data")
plt.ylabel("Frequency")
plt.hist(x, bins = 10, color = 'green') # bins = จำนวนแท่งที่ต้องการ
plt.show()

# %% [markdown]
# ### Scatter Plot and 3-D plotting

# %%
height = np.array([167,170,149,165,155,180,166,146,159,185,145,168,172,181,169])

weight = np.array([85,74,66,78,68,79,90,73,70,88,66,84,67,84,77])

plt.xlim(140,200) # กำหนดช่วงข้อมูลแกน X

plt.ylim(60,100) #  กำหนดช่วงข้อมูลแกน Y

plt.scatter(height, weight)

plt.title("Scatter Plot")

plt.xlabel("Height")

plt.ylabel("Weight")

plt.show()

# %% [markdown]
# #### Mplot3d
# https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html

# %%
from mpl_toolkits import mplot3d

# %%
ax = plt.axes(projection = '3d')

ax.scatter3D(height, weight)

ax.set_xlabel('Height')

ax.set_ylabel('Weight')

plt.show()

# %%
ax = plt.axes(projection = '3d')

ax.plot3D(height, weight)

ax.set_xlabel('Height')

ax.set_ylabel('Weight')

plt.show()

# %% [markdown]
# ## Show Matplotlit Control in Cell

# %%
x = [1,2,3,4]

y = [1,4,9,16]

# %%
plt.plot(x,y,'-b') # -b = line + blue

plt.show()

# %%
# %matplotlib notebook

# %%
plt.plot(x,y,'-b') # -b = line + blue

plt.show()
# Out:
# <div id='4a39972a-946d-491e-8896-e9ca91fc616f'></div>

# %%
# %matplotlib inline

# %% [markdown]
# ## Seaborn
#
# https://www.c-sharpcorner.com/article/a-complete-python-seaborn-tutorial/

# %%
import pandas as pd

# Seaborn for plotting and styling
import seaborn as sns

# %%
tips = pd.read_csv("data set/tips.csv")

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Seaborn's plotting functions.
# https://seaborn.pydata.org/generated/seaborn.lmplot.html?highlight=lmplot#seaborn.lmplot

# %%
# Recommended way
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
# Scatterplot arguments
sns.lmplot(x = 'total_bill', y = 'tip', data=tips
           ,fit_reg = False # No regression line
           ,hue ='sex')   # Color by evolution stage

# %% [markdown]
# ### Customizing with Matplotlib.

# %%
# Plot uing Seaborn
sns.lmplot(x = 'total_bill', y = 'tip', data = tips
           ,fit_reg = False
           ,hue = 'sex')

# Tweak using Matplotlib
plt.ylim(0, None)
plt.xlim(0, None)
# Out:
# (0.0, 53.197)

# %% [markdown]
# ### Box Plot
# https://seaborn.pydata.org/generated/seaborn.boxplot.html?highlight=boxplot#seaborn.boxplot

# %%
# Boxplot

sns.boxplot(data = tips)
# Out:
# <Axes: >

# %%
stats_tips = tips.drop(['total_bill'], axis = 1)

sns.boxplot(data = stats_tips)
# Out:
# <Axes: >

# %% [markdown]
# ### Violinplot
# https://seaborn.pydata.org/generated/seaborn.violinplot.html?highlight=violinplot#seaborn.violinplot

# %%
# Set theme
sns.set_style('whitegrid')
 
# Violin plot
sns.violinplot(x='size', y='tip', data=tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Color palettes.

# %%
sex_type_colors = ['#78C850',  # 1
                    '#F08030',  # 2
                    '#6890F0',  # 3
                    '#A8B820',  # 4
                    '#A8A878',  # 5
                    '#A040A0',  # 6
                   ]

# %%
sns.violinplot(x='size', y='tip', data = tips, palette=sex_type_colors) # Set color palette
# Out:
# C:\Users\Kiang\AppData\Local\Temp\ipykernel_20464\972373499.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='size', y='tip', data = tips, palette=sex_type_colors) # Set color palette
# <Axes: xlabel='size', ylabel='tip'>

# %% [markdown]
# ### Swarm Plot
# https://seaborn.pydata.org/generated/seaborn.swarmplot.html?highlight=swarmplot#seaborn.swarmplot

# %%
# Swarm plot with Pokemon color palette
sns.swarmplot(x='size', y='tip', data=tips, palette=sex_type_colors)
# Out:
# C:\Users\Kiang\AppData\Local\Temp\ipykernel_20464\2242413667.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='size', y='tip', data=tips, palette=sex_type_colors)
# C:\Users\Kiang\miniforge3\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 30.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='size', ylabel='tip'>
# C:\Users\Kiang\miniforge3\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Overlaying plots

# %%
# Set figure size with matplotlib
plt.figure(figsize=(10,6))
 
# Create plot
sns.violinplot(x='size',
               y='tip', 
               data=tips, 
               inner=None, # Remove the bars inside the violins
               palette=sex_type_colors)
 
sns.swarmplot(x='size', 
              y='tip', 
              data=tips, 
              color='k', # Make points black
              alpha=0.7) # and slightly transparent
 
# Set title with matplotlib
plt.title('tip by sex')
# Out:
# C:\Users\Kiang\AppData\Local\Temp\ipykernel_20464\1627616796.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='size',
# C:\Users\Kiang\miniforge3\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'tip by sex')
# C:\Users\Kiang\miniforge3\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Heatmap
# https://seaborn.pydata.org/generated/seaborn.heatmap.html?highlight=heatmap#seaborn.heatmap

# %%
corr = stats_tips.corr()

# Heatmap
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 corr = stats_tips.corr()
#       3 # Heatmap
#       4 sns.heatmap(corr)
#
# File ~\miniforge3\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\miniforge3\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\miniforge3\lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\miniforge3\lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Female'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Histogram
#
# https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
sns.distplot(tips.tip)

# %% [markdown]
# ### Bar plot
#
# https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
sns.barplot(x="day", y="total_bill", data=tips, palette=sex_type_colors)
    
    
# Rotate x-labels
plt.xticks(rotation=-45)

# %%
# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='sex', data=tips, palette=sex_type_colors)

# Rotate x-labels
plt.xticks(rotation=-45)

# %% [markdown]
# ### Factor Plot

# %%
# Factor Plot
g = sns.factorplot(x='size', 
                   y='tip', 
                   data=tips, 
                   hue='sex',  # Color by stage
                   col='sex',  # Separate by stage
                   kind='swarm') # Swarmplot
 
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)
 
# Doesn't work because only rotates last plot
# plt.xticks(rotation=-45)

# %% [markdown]
# ### Density Plot
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html?highlight=kdeplot#seaborn.kdeplot

# %%
# Density Plot
sns.kdeplot(tips.total_bill, tips.tip)

# %% [markdown]
# ### Joint Distribution Plot
# https://seaborn.pydata.org/generated/seaborn.jointplot.html?highlight=jointplot#seaborn.jointplot

# %%
# Joint Distribution Plot
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot("total_bill", "tip", data=tips, kind="hex")
