# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(r"C:\Users\Kiang\OneDrive\Documents\ledger.xlsx")

# %%
columns_to_remove = ["KB2KT", "KB2B", "KT2KB", "KT2B", "KT2W", "W2KT"]

df_new = df[[col for col in df.columns if col not in columns_to_remove]]

df_new
# Out:
#           Date  Available  W Income  W Outcome  W Net Worth  KB Income  \
# 0   2022-10-01  19763.580         0       55.0      1669.50        0.0
# 1   2022-10-02  11875.580       520     8408.0       781.50        0.0
# 2   2022-10-03  10648.580         0        0.0       781.50        0.0
# 3   2022-10-04  10438.580         0        0.0       781.50        0.0
# 4   2022-10-05  10228.580         0        0.0       781.50        0.0
# ..         ...        ...       ...        ...          ...        ...
# 789 2024-11-28     60.005         0        0.0      1705.75        0.0
# 790 2024-11-29   -104.995         0        0.0      1705.75        0.0
# 791 2024-11-30   -269.995         0        0.0      1705.75        0.0
# 792 2024-12-01   -434.995         0        0.0      1705.75        0.0
# 793 2024-12-02   -599.995         0        0.0      1705.75        0.0
#
#      KB Outcome  KB Net Worth  KT Income  KT Outcome  ...  B Net Worth  \
# 0          60.0        250.00    12000.0           0  ...       121.15
# 1           0.0       1750.00        0.0           0  ...       121.15
# 2        1227.0        523.00        0.0           0  ...       121.15
# 3           0.0        523.00        0.0         200  ...       121.15
# 4           0.0        523.00        0.0           0  ...       121.15
# ..          ...           ...        ...         ...  ...          ...
# 789         0.0       3992.42        0.0           0  ...        48.92
# 790         0.0       3992.42        0.0           0  ...        48.92
# 791         0.0       3992.42        0.0           0  ...        48.92
# 792         0.0       3992.42        0.0           0  ...        48.92
# 793         0.0       3992.42        0.0           0  ...        48.92
#
#      Total Income  Total Outcome  Overbudget  Special  Daily Saving  \
# 0         12000.0          465.0           1        0           0.0
# 1           520.0         8408.0           0        1           NaN
# 2             0.0         1227.0           1        0           0.0
# 3             0.0          200.0           0        0          10.0
# 4             0.0            0.0           0        0         210.0
# ..            ...            ...         ...      ...           ...
# 789           0.0            0.0           0        0         165.0
# 790           0.0            0.0           0        0         165.0
# 791           0.0            0.0           0        0         165.0
# 792           0.0            0.0           0        0         165.0
# 793           0.0            0.0           0        0         165.0
#
#         Saving  Extra  Net Worth  Investment
# 0      777.070 -350.0   20540.65         NaN
# 1      777.070    NaN   12652.65         NaN
# 2      777.070    NaN   11425.65         NaN
# 3      787.070    NaN   11225.65         NaN
# 4      997.070    NaN   11225.65         NaN
# ..         ...    ...        ...         ...
# 789  18687.085    NaN   18747.09         NaN
# 790  18852.085    NaN   18747.09         NaN
# 791  19017.085    NaN   18747.09         NaN
# 792  19182.085    NaN   18747.09         NaN
# 793  19347.085    NaN   18747.09         NaN
#
# [794 rows x 25 columns]

# %%
overview = df[["Date", "Available", "Saving", "Net Worth"]].set_index("Date")

monthly = overview.loc[["2022-10-01", "2022-11-01", "2022-12-01",
              "2023-01-01", "2023-02-01", "2023-03-01",
              "2023-04-01", "2023-05-01", "2023-06-01",
              "2023-07-01", "2023-08-01", "2023-09-01",
              "2023-10-01", "2023-11-01", "2023-12-01",
              "2024-01-01", "2024-02-01", "2024-03-01",
              "2024-04-01", "2024-05-01", "2024-06-01",
              "2024-07-01", "2024-08-01", "2024-09-01",
              ]]

# monthly

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly[["Available", "Saving", "Net Worth"]])

plt.title("Financial Comparison Over Time")
plt.xlabel("Date")
plt.ylabel("Amount")
plt.xticks(rotation=45)
plt.legend(title="Category")

plt.tight_layout()

plt.show()
# Out:
# c:\Users\Kiang\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Kiang\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
