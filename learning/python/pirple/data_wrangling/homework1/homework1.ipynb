# %% [markdown]
# # Homework 1

# %%
import pandas as pd

df = pd.read_csv("List_of_Orders.csv")

# %%
# determine the number of rows and columns in the data
df.shape
# Out:
# (500, 5)

# %%
# display a small sample of the data
# before
df.head(15)
# Out:
#    Order_ID  Order_Date CustomerName              State                City
# 0   B-25601    1/4/2018       Bharat            Gujarat           Ahmedabad
# 1   B-25602    1/4/2018        Pearl        Maharashtra                Pune
# 2   B-25603    3/4/2018        Jahan     Madhya Pradesh              Bhopal
# 3   B-25604    3/4/2018       Divsha          Rajasthan              Jaipur
# 4   B-25605    5/4/2018      Kasheen        West Bengal             Kolkata
# 5   B-25606    6/4/2018        Hazel          Karnataka           Bangalore
# 6   B-25607    6/4/2018     Sonakshi  Jammu and Kashmir             Kashmir
# 7   B-25608    8/4/2018      Aarushi         Tamil Nadu             Chennai
# 8   B-25609    9/4/2018       Jitesh      Uttar Pradesh             Lucknow
# 9   B-25610    9/4/2018       Yogesh              Bihar               Patna
# 10  B-25611   11/4/2018        Anita            Kerala   Thiruvananthapuram
# ...

# %%
# create new dataframe
df['OrderDate'] = pd.to_datetime(df.Order_Date)

# display day name
df['day of the week'] = df.OrderDate.dt.day_name()

# display 15 rows
df['day of the week'].head(15)
# Out:
# 0     Thursday
# 1     Thursday
# 2       Sunday
# 3       Sunday
# 4       Friday
# 5       Monday
# 6       Monday
# 7     Saturday
# 8      Tuesday
# 9      Tuesday
# 10      Sunday
# 11     Tuesday
# 12     Tuesday
# 13      Friday
# 14      Sunday
# Name: day of the week, dtype: object

# %%
# after
df.head(15)
# Out:
#    Order_ID  Order_Date CustomerName              State                City  \
# 0   B-25601    1/4/2018       Bharat            Gujarat           Ahmedabad
# 1   B-25602    1/4/2018        Pearl        Maharashtra                Pune
# 2   B-25603    3/4/2018        Jahan     Madhya Pradesh              Bhopal
# 3   B-25604    3/4/2018       Divsha          Rajasthan              Jaipur
# 4   B-25605    5/4/2018      Kasheen        West Bengal             Kolkata
# 5   B-25606    6/4/2018        Hazel          Karnataka           Bangalore
# 6   B-25607    6/4/2018     Sonakshi  Jammu and Kashmir             Kashmir
# 7   B-25608    8/4/2018      Aarushi         Tamil Nadu             Chennai
# 8   B-25609    9/4/2018       Jitesh      Uttar Pradesh             Lucknow
# 9   B-25610    9/4/2018       Yogesh              Bihar               Patna
# 10  B-25611   11/4/2018        Anita            Kerala   Thiruvananthapuram
# ...
